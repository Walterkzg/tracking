# %%
HOME = 'D:\\software\\LocalProjects\\VehicleTracking\\ultralytics\\yolo\\v8\\detect'

# %%
# %cd {HOME}
# Out:
# D:\software\LocalProjects\VehicleTracking\ultralytics\yolo\v8\detect

# %%
# !python predict.py model=best.pt source=input.mp4 +project=. +name=output
# !python predict_vis.py model=yolov8n.pt source=input.mp4 +project=. +name=output ++save=True
#!python predict_vis.py model={model_path} source={video_path} +project={output_dir} +name=exp +save-frames
# Out:
# 当前工作目录: D:\software\LocalProjects\VehicleTracking\ultralytics\yolo\v8\detect
# 脚本所在目录: D:\software\LocalProjects\VehicleTracking\ultralytics\yolo\v8\detect
# [2025-05-15 10:14:56,016][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
# 视频写入器已初始化 | 分辨率: 1280x720 | 帧率: 30
# Object ID类型检查: <class 'numpy.int64'>, 值: 2
# ...
